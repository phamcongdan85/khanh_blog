# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

img = plt.imread('data/laver.jpg', cv2.IMREAD_UNCHANGED)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print('image shape', img.shape)
print('gray shape', gray.shape)

plt.figure(figsize=(16,14))
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.title('Original Image')
plt.subplot(1,2,2)
plt.imshow(gray)
plt.title('Gray image')
plt.axis('off')
plt.show()
# Out:
# image shape (1200, 1800, 3)
# gray shape (1200, 1800)

# %%
# calculate graditent gx, gy

gx = cv2.Sobel(gray, cv2.CV_32F, dx = 0, dy = 1, ksize=3)
gy = cv2.Sobel(gray, cv2.CV_32F, dx = 1, dy = 0, ksize=3)

print('gray shape: {}'.format(gray.shape))
print('gx shape: {}'.format(gx.shape))
print('gy shape: {}'.format(gy.shape))
# Out:
# gray shape: (1200, 1800)
# gx shape: (1200, 1800)
# gy shape: (1200, 1800)

# %%
g, theta = cv2.cartToPolar(gx, gy, angleInDegrees=True)
print('gradient format:{}'.format(g.shape))
print('theta format: {}'.format(theta.shape))
# Out:
# gradient format:(1200, 1800)
# theta format: (1200, 1800)

# %%
w = 20
h = 10

plt.figure(figsize=(w,h))
plt.subplot(1,4,1)
plt.title('gradient of x')
plt.imshow(gx)
plt.axis('off')

plt.figure(figsize=(w,h))
plt.subplot(1,4,2)
plt.title('gradient of y')
plt.imshow(gy)
plt.axis('off')

plt.subplot(1, 4, 3)
plt.title('Magnitute of gradient')
plt.imshow(g)
plt.axis('off')


plt.subplot(1, 4, 4)
plt.title('Direction of gradient')
plt.imshow(theta)
plt.axis('off')


plt.show()
